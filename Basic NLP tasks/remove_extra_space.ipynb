# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshkumar1887/DSA-in-java/blob/main/Basic%20NLP%20tasks/remove_extra_space.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

text = "This   is   NLP    preprocessing"

clean_text = re.sub(r'\s+',' ',text)

print(clean_text)
# Out:
# This is NLP preprocessing

# %% [markdown]
# **Leading aur Trailing Spaces Remove**

# %%
text = "   Hello NLP World   "

clean_text = text.strip()

print(clean_text)
# Out:
# Hello NLP World
